# %% [markdown]
# # God'swill Pandas Assignment on Data cleaning,wringling etc...

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\User\Downloads\messy_data.csv")

# %%
data.head()
# Out:
#    TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  TtlSales  \
# 0     7402  03/17/2026      991     1045     Boo E       9  167.72   2935.06
# 1     5835  26-01-2035      741     1040    Book J      18  193.27   4386.52
# 2     2123  05/26/2035      933     1062     Bok N       5  126.39   1948.46
# 3     8789  28-02-2036      641     1060    Book I       6   66.98   1757.26
# 4      305  19-04-2023      123     1058    Book B      15   33.63   2578.19
#
#   PaymentType  CusterAge
# 0         NaN         87
# 1  debit card         69
# 2        Cash         15
# 3        Cash         22
# 4        Cash         -1

# %%
data.rename(columns = {"TrnsnID":"TransactionID"}, inplace = True)

# %%
data
# Out:
#        TransactionID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 0               7402  03/17/2026      991     1045     Boo E       9  167.72
# 1               5835  26-01-2035      741     1040    Book J      18  193.27
# 2               2123  05/26/2035      933     1062     Bok N       5  126.39
# 3               8789  28-02-2036      641     1060    Book I       6   66.98
# 4                305  19-04-2023      123     1058    Book B      15   33.63
# ...              ...         ...      ...      ...       ...     ...     ...
# 10095           5735  04/03/2027       52     1066    Book G       1  191.41
# 10096           5192  08/16/2025      334     1093     Bok N      -2  186.16
# 10097           5391  06/18/2026      657     1047   Bookk H       5   84.38
# 10098            861  04/08/2034      579     1014     Bok N      19  137.58
# 10099           7271  26-04-2029      153     1052    Book T      10  159.98
#
#        TtlSales  PaymentType  CusterAge
# ...

# %%
data.rename(columns = {"Data":"Date"}, inplace = True)
data.rename(columns = {"CusmrID":"CustomerID"}, inplace = True)
data.rename(columns = {"ProdtID":"ProductID"}, inplace = True)
data.rename(columns = {"ProdtName":"ProductName"}, inplace = True)
data.rename(columns = {"Qutity":"Quantity"}, inplace = True)
data.rename(columns = {"TtlSales":"TotalSales"}, inplace = True)
data.rename(columns = {"CusterAge":"CustomerAge"}, inplace = True)
data.rename(columns = {"Prize":"Price"}, inplace = True)

# %%
data
# Out:
#        TransactionID        Date  CustomerID  ProductID ProductName  Quantity  \
# 0               7402  03/17/2026         991       1045       Boo E         9
# 1               5835  26-01-2035         741       1040      Book J        18
# 2               2123  05/26/2035         933       1062       Bok N         5
# 3               8789  28-02-2036         641       1060      Book I         6
# 4                305  19-04-2023         123       1058      Book B        15
# ...              ...         ...         ...        ...         ...       ...
# 10095           5735  04/03/2027          52       1066      Book G         1
# 10096           5192  08/16/2025         334       1093       Bok N        -2
# 10097           5391  06/18/2026         657       1047     Bookk H         5
# 10098            861  04/08/2034         579       1014       Bok N        19
# 10099           7271  26-04-2029         153       1052      Book T        10
#
# ...

# %%
data.isna()
# Out:
#        TransactionID   Date  CustomerID  ProductID  ProductName  Quantity  \
# 0              False  False       False      False        False     False
# 1              False  False       False      False        False     False
# 2              False  False       False      False        False     False
# 3              False  False       False      False        False     False
# 4              False  False       False      False        False     False
# ...              ...    ...         ...        ...          ...       ...
# 10095          False  False       False      False        False     False
# 10096          False  False       False      False        False     False
# 10097          False  False       False      False        False     False
# 10098          False  False       False      False        False     False
# 10099          False  False       False      False        False     False
#
#        Price  TotalSales  PaymentType  CustomerAge
# ...

# %%
data.fillna(method = "bfill",inplace = True)

# %%
data.tail(10)
# Out:
#        TransactionID        Date  CustomerID  ProductID ProductName  Quantity  \
# 10090           8323  15-03-2033         157       1090       Boo E         1
# 10091           5579  10/28/2024         276       1007      Book S        15
# 10092           4427  24-01-2026         386       1018       Boo E        14
# 10093            467  05/06/2032         564       1095       Boo E        -3
# 10094           6266  01/06/2034         804       1051       Boo E        -2
# 10095           5735  04/03/2027          52       1066      Book G         1
# 10096           5192  08/16/2025         334       1093       Bok N        -2
# 10097           5391  06/18/2026         657       1047     Bookk H         5
# 10098            861  04/08/2034         579       1014       Bok N        19
# 10099           7271  26-04-2029         153       1052      Book T        10
#
#         Price  TotalSales  PaymentType  CustomerAge
# 10090   76.06     3288.01   debit card            3
# ...

# %%
data.describe()
# Out:
#        TransactionID    CustomerID     ProductID      Quantity         Price  \
# count   10100.000000  10100.000000  10100.000000  10100.000000  10100.000000
# mean     5000.546634    503.805050   1049.607228      7.028119    102.397194
# std      2886.964892    289.143863     28.931014      7.207902     56.429556
# min         1.000000      1.000000   1000.000000     -5.000000      5.030000
# 25%      2504.750000    255.000000   1024.000000      1.000000     54.095000
# 50%      4998.500000    507.500000   1050.000000      7.000000    102.080000
# 75%      7502.250000    759.000000   1074.000000     13.000000    151.647500
# max     10000.000000    999.000000   1099.000000     19.000000    199.980000
#
#          TotalSales   CustomerAge
# count  10100.000000  10100.000000
# mean    2521.484192     44.456832
# std     1431.601571     32.037813
# min       20.460000    -10.000000
# 25%     1288.860000     17.000000
# 50%     2520.870000     45.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10100 entries, 0 to 10099
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  10100 non-null  int64
#  1   Date           10100 non-null  object
#  2   CustomerID     10100 non-null  int64
#  3   ProductID      10100 non-null  int64
#  4   ProductName    10100 non-null  object
#  5   Quantity       10100 non-null  int64
#  6   Price          10100 non-null  float64
#  7   TotalSales     10100 non-null  float64
#  8   PaymentType    10100 non-null  object
#  9   CustomerAge    10100 non-null  int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 789.2+ KB

# %%
data["CustomerAge"]=data["CustomerAge"].abs()

# %%
data.tail(10)
# Out:
#        TransactionID        Date  CustomerID  ProductID ProductName  Quantity  \
# 10090           8323  15-03-2033         157       1090       Boo E         1
# 10091           5579  10/28/2024         276       1007      Book S        15
# 10092           4427  24-01-2026         386       1018       Boo E        14
# 10093            467  05/06/2032         564       1095       Boo E        -3
# 10094           6266  01/06/2034         804       1051       Boo E        -2
# 10095           5735  04/03/2027          52       1066      Book G         1
# 10096           5192  08/16/2025         334       1093       Bok N        -2
# 10097           5391  06/18/2026         657       1047     Bookk H         5
# 10098            861  04/08/2034         579       1014       Bok N        19
# 10099           7271  26-04-2029         153       1052      Book T        10
#
#         Price  TotalSales  PaymentType  CustomerAge
# 10090   76.06     3288.01   debit card            3
# ...

# %%
data["Quantity"]=data["Quantity"].abs()

# %%
data.tail(10)
# Out:
#        TransactionID        Date  CustomerID  ProductID ProductName  Quantity  \
# 10090           8323  15-03-2033         157       1090       Boo E         1
# 10091           5579  10/28/2024         276       1007      Book S        15
# 10092           4427  24-01-2026         386       1018       Boo E        14
# 10093            467  05/06/2032         564       1095       Boo E         3
# 10094           6266  01/06/2034         804       1051       Boo E         2
# 10095           5735  04/03/2027          52       1066      Book G         1
# 10096           5192  08/16/2025         334       1093       Bok N         2
# 10097           5391  06/18/2026         657       1047     Bookk H         5
# 10098            861  04/08/2034         579       1014       Bok N        19
# 10099           7271  26-04-2029         153       1052      Book T        10
#
#         Price  TotalSales  PaymentType  CustomerAge
# 10090   76.06     3288.01   debit card            3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10100 entries, 0 to 10099
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  10100 non-null  int64
#  1   Date           10100 non-null  object
#  2   CustomerID     10100 non-null  int64
#  3   ProductID      10100 non-null  int64
#  4   ProductName    10100 non-null  object
#  5   Quantity       10100 non-null  int64
#  6   Price          10100 non-null  float64
#  7   TotalSales     10100 non-null  float64
#  8   PaymentType    10100 non-null  object
#  9   CustomerAge    10100 non-null  int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 789.2+ KB

# %%
data.Date = data.Date.str.replace('-','/')

# %%
data.tail(10)
# Out:
#        TransactionID        Date  CustomerID  ProductID ProductName  Quantity  \
# 10090           8323  15/03/2033         157       1090       Boo E         1
# 10091           5579  10/28/2024         276       1007      Book S        15
# 10092           4427  24/01/2026         386       1018       Boo E        14
# 10093            467  05/06/2032         564       1095       Boo E         3
# 10094           6266  01/06/2034         804       1051       Boo E         2
# 10095           5735  04/03/2027          52       1066      Book G         1
# 10096           5192  08/16/2025         334       1093       Bok N         2
# 10097           5391  06/18/2026         657       1047     Bookk H         5
# 10098            861  04/08/2034         579       1014       Bok N        19
# 10099           7271  26/04/2029         153       1052      Book T        10
#
#         Price  TotalSales  PaymentType  CustomerAge
# 10090   76.06     3288.01   debit card            3
# ...

# %%
data.Date = pd.to_datetime(data.Date,format = 'mixed')

# %%
data.Date = pd.to_datetime(data.Date,format = 'dayfirst')

# %%
data.head(20)
# Out:
#     TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 0            7402 2026-03-17         991       1045       Boo E         9
# 1            5835 2035-01-26         741       1040      Book J        18
# 2            2123 2035-05-26         933       1062       Bok N         5
# 3            8789 2036-02-28         641       1060      Book I         6
# 4             305 2023-04-19         123       1058      Book B        15
# 5            2532 2032-08-19         185       1090       Bok N        12
# 6            2996 2031-04-03         571       1086      Book D        15
# 7            7660 2031-02-27         172       1012      Book P        12
# 8            8225 2026-05-26         342       1098      Book P        11
# 9            4449 2030-02-05         614       1086      Book M         5
# 10           3621 2036-05-08         755       1051       Boo E        19
# 11           9211 2035-07-18         361       1020      Book O        14
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10100 entries, 0 to 10099
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  10100 non-null  int64
#  1   Date           10100 non-null  datetime64[ns]
#  2   CustomerID     10100 non-null  int64
#  3   ProductID      10100 non-null  int64
#  4   ProductName    10100 non-null  object
#  5   Quantity       10100 non-null  int64
#  6   Price          10100 non-null  float64
#  7   TotalSales     10100 non-null  float64
#  8   PaymentType    10100 non-null  object
#  9   CustomerAge    10100 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(2)
# memory usage: 789.2+ KB

# %%
data.PaymentType = data.PaymentType.str.replace('debit','Debit Card')

# %%
data
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 0               7402 2026-03-17         991       1045       Boo E         9
# 1               5835 2035-01-26         741       1040      Book J        18
# 2               2123 2035-05-26         933       1062       Bok N         5
# 3               8789 2036-02-28         641       1060      Book I         6
# 4                305 2023-04-19         123       1058      Book B        15
# ...              ...        ...         ...        ...         ...       ...
# 10095           5735 2027-04-03          52       1066      Book G         1
# 10096           5192 2025-08-16         334       1093       Bok N         2
# 10097           5391 2026-06-18         657       1047     Bookk H         5
# 10098            861 2034-04-08         579       1014       Bok N        19
# 10099           7271 2029-04-26         153       1052      Book T        10
#
# ...

# %%
data.PaymentType = data.PaymentType.str.replace('Debit','Debit Card')

# %%
data
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 0               7402 2026-03-17         991       1045       Boo E         9
# 1               5835 2035-01-26         741       1040      Book J        18
# 2               2123 2035-05-26         933       1062       Bok N         5
# 3               8789 2036-02-28         641       1060      Book I         6
# 4                305 2023-04-19         123       1058      Book B        15
# ...              ...        ...         ...        ...         ...       ...
# 10095           5735 2027-04-03          52       1066      Book G         1
# 10096           5192 2025-08-16         334       1093       Bok N         2
# 10097           5391 2026-06-18         657       1047     Bookk H         5
# 10098            861 2034-04-08         579       1014       Bok N        19
# 10099           7271 2029-04-26         153       1052      Book T        10
#
# ...

# %%
data.PaymentType = data.PaymentType.str.replace('Debit Card Card','Debit Card')

# %%
data
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 0               7402 2026-03-17         991       1045       Boo E         9
# 1               5835 2035-01-26         741       1040      Book J        18
# 2               2123 2035-05-26         933       1062       Bok N         5
# 3               8789 2036-02-28         641       1060      Book I         6
# 4                305 2023-04-19         123       1058      Book B        15
# ...              ...        ...         ...        ...         ...       ...
# 10095           5735 2027-04-03          52       1066      Book G         1
# 10096           5192 2025-08-16         334       1093       Bok N         2
# 10097           5391 2026-06-18         657       1047     Bookk H         5
# 10098            861 2034-04-08         579       1014       Bok N        19
# 10099           7271 2029-04-26         153       1052      Book T        10
#
# ...

# %%
data.PaymentType = data.PaymentType.str.replace('paypal','PayPal')

# %%
data.PaymentType = data.PaymentType.str.replace('credit','Credit Card')

# %%
data.PaymentType = data.PaymentType.str.replace('Credit','Credit Card')

# %%
data.PaymentType = data.PaymentType.str.replace('Credit Card Card','Credit Card')

# %%
data.ProductName = data.ProductName.str.replace('Boo','Book')
data.ProductName = data.ProductName.str.replace('Bookk','Book')
data.ProductName = data.ProductName.str.replace('Bookkk','Book')

# %%
data.ProductName = data.ProductName.str.replace('Bookk','Book')

# %%
data.sample(20)
# Out:
#       TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 8563           7058 2033-11-12         709       1039      Book I         5
# 5785           7363 2030-02-21         337       1070      Book M         2
# 8697           4812 2032-03-08         306       1011      Book E        16
# 3078           6148 2032-05-18         194       1063      Book A        12
# 2350           8958 2025-10-13         695       1009      Book P         8
# 2923           1657 2029-11-18          97       1000       Bok N         9
# 21             6283 2026-04-13         632       1049      Book P        12
# 6527           9605 2026-02-24         762       1008      Book H        11
# 2446           6088 2033-06-21          78       1091      Book O        12
# 3758            939 2027-12-14         306       1076      Book H         7
# 1415           4316 2034-04-05           6       1080      Book B        13
# ...

# %%
data.describe()
# Out:
#        TransactionID                           Date    CustomerID  \
# count   10100.000000                          10100  10100.000000
# mean     5000.546634  2029-11-06 13:18:59.168316928    503.805050
# min         1.000000            2023-01-01 00:00:00      1.000000
# 25%      2504.750000            2026-06-03 00:00:00    255.000000
# 50%      4998.500000            2029-11-05 00:00:00    507.500000
# 75%      7502.250000            2033-04-10 06:00:00    759.000000
# max     10000.000000            2036-12-08 00:00:00    999.000000
# std      2886.964892                            NaN    289.143863
#
#           ProductID      Quantity         Price    TotalSales   CustomerAge
# count  10100.000000  10100.000000  10100.000000  10100.000000  10100.000000
# mean    1049.607228      8.195644    102.397194   2521.484192     45.514455
# min     1000.000000      0.000000      5.030000     20.460000      0.000000
# ...

# %%
data.loc[data['Quantity']==0, 'Quantity'] = 8

# %%
data
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 0               7402 2026-03-17         991       1045      Book E         9
# 1               5835 2035-01-26         741       1040      Book J        18
# 2               2123 2035-05-26         933       1062       Bok N         5
# 3               8789 2036-02-28         641       1060      Book I         6
# 4                305 2023-04-19         123       1058      Book B        15
# ...              ...        ...         ...        ...         ...       ...
# 10095           5735 2027-04-03          52       1066      Book G         1
# 10096           5192 2025-08-16         334       1093       Bok N         2
# 10097           5391 2026-06-18         657       1047      Book H         5
# 10098            861 2034-04-08         579       1014       Bok N        19
# 10099           7271 2029-04-26         153       1052      Book T        10
#
# ...

# %%
data.sample(20)
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 3299            3911 2030-12-29         134       1052      Book F        18
# 9155            2372 2032-08-12         719       1092      Book E        13
# 6392            8375 2030-02-08         285       1091      Book A         4
# 81              5401 2030-08-05         953       1095      Book T        14
# 3439            2224 2035-01-29         242       1068      Book P        16
# 1089            9627 2023-11-12         967       1001      Book G        10
# 5676            2309 2033-06-23         208       1065       Bok N        13
# 3837            9146 2034-12-14         741       1045      Book E         4
# 9040            5955 2032-12-06         513       1095      Book A        12
# 7598            5202 2023-12-11         954       1047      Book E         4
# 7599            8085 2033-03-28         562       1014      Book M         3
# ...

# %%
data.duplicated()
# Out:
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 10096    False
# 10097    False
# 10098    False
# 10099    False
# 10100    False
# Length: 10100, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [TransactionID, Date, CustomerID, ProductID, ProductName, Quantity, Price, TotalSales, PaymentType, CustomerAge]
# Index: []

# %%
data.drop_duplicates(inplace = True)

# %%
data
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 1               7402 2026-03-17         991       1045      Book E         9
# 2               5835 2035-01-26         741       1040      Book J        18
# 3               2123 2035-05-26         933       1062       Bok N         5
# 4               8789 2036-02-28         641       1060      Book I         6
# 5                305 2023-04-19         123       1058      Book B        15
# ...              ...        ...         ...        ...         ...       ...
# 10096           5735 2027-04-03          52       1066      Book G         1
# 10097           5192 2025-08-16         334       1093       Bok N         2
# 10098           5391 2026-06-18         657       1047      Book H         5
# 10099            861 2034-04-08         579       1014       Bok N        19
# 10100           7271 2029-04-26         153       1052      Book T        10
#
# ...

# %%
indexes = [i for i in range(1,10022)]
data.index = indexes

# %%
data
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 1               7402 2026-03-17         991       1045      Book E         9
# 2               5835 2035-01-26         741       1040      Book J        18
# 3               2123 2035-05-26         933       1062       Bok N         5
# 4               8789 2036-02-28         641       1060      Book I         6
# 5                305 2023-04-19         123       1058      Book B        15
# ...              ...        ...         ...        ...         ...       ...
# 10017           5735 2027-04-03          52       1066      Book G         1
# 10018           5192 2025-08-16         334       1093       Bok N         2
# 10019           5391 2026-06-18         657       1047      Book H         5
# 10020            861 2034-04-08         579       1014       Bok N        19
# 10021           7271 2029-04-26         153       1052      Book T        10
#
# ...

# %%
data
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 1               7402 2026-03-17         991       1045      Book E         9
# 2               5835 2035-01-26         741       1040      Book J        18
# 3               2123 2035-05-26         933       1062       Bok N         5
# 4               8789 2036-02-28         641       1060      Book I         6
# 5                305 2023-04-19         123       1058      Book B        15
# ...              ...        ...         ...        ...         ...       ...
# 10017           5735 2027-04-03          52       1066      Book G         1
# 10018           5192 2025-08-16         334       1093       Bok N         2
# 10019           5391 2026-06-18         657       1047      Book H         5
# 10020            861 2034-04-08         579       1014       Bok N        19
# 10021           7271 2029-04-26         153       1052      Book T        10
#
# ...

# %%
data.PaymentType = data.PaymentType.str.replace('Debit Card Card','Debit Card')

# %%
data
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 1               7402 2026-03-17         991       1045      Book E         9
# 2               5835 2035-01-26         741       1040      Book J        18
# 3               2123 2035-05-26         933       1062       Bok N         5
# 4               8789 2036-02-28         641       1060      Book I         6
# 5                305 2023-04-19         123       1058      Book B        15
# ...              ...        ...         ...        ...         ...       ...
# 10017           5735 2027-04-03          52       1066      Book G         1
# 10018           5192 2025-08-16         334       1093       Bok N         2
# 10019           5391 2026-06-18         657       1047      Book H         5
# 10020            861 2034-04-08         579       1014       Bok N        19
# 10021           7271 2029-04-26         153       1052      Book T        10
#
# ...

# %%
data.PaymentType = data.PaymentType.str.replace('Debit Card Card','Debit Card')

# %%
data
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 1               7402 2026-03-17         991       1045      Book E         9
# 2               5835 2035-01-26         741       1040      Book J        18
# 3               2123 2035-05-26         933       1062       Bok N         5
# 4               8789 2036-02-28         641       1060      Book I         6
# 5                305 2023-04-19         123       1058      Book B        15
# ...              ...        ...         ...        ...         ...       ...
# 10017           5735 2027-04-03          52       1066      Book G         1
# 10018           5192 2025-08-16         334       1093       Bok N         2
# 10019           5391 2026-06-18         657       1047      Book H         5
# 10020            861 2034-04-08         579       1014       Bok N        19
# 10021           7271 2029-04-26         153       1052      Book T        10
#
# ...

# %%
data.PaymentType = data.PaymentType.str.replace('Debit Card card','Debit Card')

# %%
data
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 1               7402 2026-03-17         991       1045      Book E         9
# 2               5835 2035-01-26         741       1040      Book J        18
# 3               2123 2035-05-26         933       1062       Bok N         5
# 4               8789 2036-02-28         641       1060      Book I         6
# 5                305 2023-04-19         123       1058      Book B        15
# ...              ...        ...         ...        ...         ...       ...
# 10017           5735 2027-04-03          52       1066      Book G         1
# 10018           5192 2025-08-16         334       1093       Bok N         2
# 10019           5391 2026-06-18         657       1047      Book H         5
# 10020            861 2034-04-08         579       1014       Bok N        19
# 10021           7271 2029-04-26         153       1052      Book T        10
#
# ...

# %%
data.sample(20)
# Out:
#       TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 4699           8862 2034-02-10         592       1073      Book O         8
# 2900           7183 2024-12-24         360       1002      Book O         9
# 707            5618 2024-03-20         105       1009      Book F         5
# 528            6973 2027-03-07          70       1057      Book J         2
# 1628           3442 2033-07-22         785       1047      Book J        11
# 9988           1900 2035-05-16         775       1074      Book E        17
# 7111           5526 2029-02-04         764       1004      Book S        16
# 1942           4503 2029-06-21         587       1083      Book T         5
# 5120           2893 2028-08-25         292       1042      Book F         4
# 2113           9282 2031-01-20          72       1094      Book A         4
# 4293           5919 2033-11-08         356       1024      Book I         9
# ...

# %%
indexes = [i for i in range(1,10022)]
data.index = indexes

# %%
data
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 1               7402 2026-03-17         991       1045      Book E         9
# 2               5835 2035-01-26         741       1040      Book J        18
# 3               2123 2035-05-26         933       1062       Bok N         5
# 4               8789 2036-02-28         641       1060      Book I         6
# 5                305 2023-04-19         123       1058      Book B        15
# ...              ...        ...         ...        ...         ...       ...
# 10017           5735 2027-04-03          52       1066      Book G         1
# 10018           5192 2025-08-16         334       1093       Bok N         2
# 10019           5391 2026-06-18         657       1047      Book H         5
# 10020            861 2034-04-08         579       1014       Bok N        19
# 10021           7271 2029-04-26         153       1052      Book T        10
#
# ...

# %%
data.head(20)
# Out:
#     TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 1            7402 2026-03-17         991       1045      Book E         9
# 2            5835 2035-01-26         741       1040      Book J        18
# 3            2123 2035-05-26         933       1062       Bok N         5
# 4            8789 2036-02-28         641       1060      Book I         6
# 5             305 2023-04-19         123       1058      Book B        15
# 6            2532 2032-08-19         185       1090       Bok N        12
# 7            2996 2031-04-03         571       1086      Book D        15
# 8            7660 2031-02-27         172       1012      Book P        12
# 9            8225 2026-05-26         342       1098      Book P        11
# 10           4449 2030-02-05         614       1086      Book M         5
# 11           3621 2036-05-08         755       1051      Book E        19
# 12           9211 2035-07-18         361       1020      Book O        14
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10021 entries, 1 to 10021
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  10021 non-null  int64
#  1   Date           10021 non-null  datetime64[ns]
#  2   CustomerID     10021 non-null  int64
#  3   ProductID      10021 non-null  int64
#  4   ProductName    10021 non-null  object
#  5   Quantity       10021 non-null  int64
#  6   Price          10021 non-null  float64
#  7   TotalSales     10021 non-null  float64
#  8   PaymentType    10021 non-null  object
#  9   CustomerAge    10021 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(2)
# memory usage: 861.2+ KB

# %%
data
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 1               7402 2026-03-17         991       1045      Book E         9
# 2               5835 2035-01-26         741       1040      Book J        18
# 3               2123 2035-05-26         933       1062       Bok N         5
# 4               8789 2036-02-28         641       1060      Book I         6
# 5                305 2023-04-19         123       1058      Book B        15
# ...              ...        ...         ...        ...         ...       ...
# 10017           5735 2027-04-03          52       1066      Book G         1
# 10018           5192 2025-08-16         334       1093       Bok N         2
# 10019           5391 2026-06-18         657       1047      Book H         5
# 10020            861 2034-04-08         579       1014       Bok N        19
# 10021           7271 2029-04-26         153       1052      Book T        10
#
# ...

# %%
data.ProductName = data.ProductName.str.replace('Bok','Book')

# %%
data
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 1               7402 2026-03-17         991       1045      Book E         9
# 2               5835 2035-01-26         741       1040      Book J        18
# 3               2123 2035-05-26         933       1062      Book N         5
# 4               8789 2036-02-28         641       1060      Book I         6
# 5                305 2023-04-19         123       1058      Book B        15
# ...              ...        ...         ...        ...         ...       ...
# 10017           5735 2027-04-03          52       1066      Book G         1
# 10018           5192 2025-08-16         334       1093      Book N         2
# 10019           5391 2026-06-18         657       1047      Book H         5
# 10020            861 2034-04-08         579       1014      Book N        19
# 10021           7271 2029-04-26         153       1052      Book T        10
#
# ...

# %%
data.ProductName = data.ProductName.str.replace(' Book','Book')

# %%
data
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 1               7402 2026-03-17         991       1045      Book E         9
# 2               5835 2035-01-26         741       1040      Book J        18
# 3               2123 2035-05-26         933       1062      Book N         5
# 4               8789 2036-02-28         641       1060      Book I         6
# 5                305 2023-04-19         123       1058      Book B        15
# ...              ...        ...         ...        ...         ...       ...
# 10017           5735 2027-04-03          52       1066      Book G         1
# 10018           5192 2025-08-16         334       1093      Book N         2
# 10019           5391 2026-06-18         657       1047      Book H         5
# 10020            861 2034-04-08         579       1014      Book N        19
# 10021           7271 2029-04-26         153       1052      Book T        10
#
# ...

# %%
data['TotalSales'] = data['Price'] * data['Quantity']

# %%
data
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 1               7402 2026-03-17         991       1045      Book E         9
# 2               5835 2035-01-26         741       1040      Book J        18
# 3               2123 2035-05-26         933       1062      Book N         5
# 4               8789 2036-02-28         641       1060      Book I         6
# 5                305 2023-04-19         123       1058      Book B        15
# ...              ...        ...         ...        ...         ...       ...
# 10017           5735 2027-04-03          52       1066      Book G         1
# 10018           5192 2025-08-16         334       1093      Book N         2
# 10019           5391 2026-06-18         657       1047      Book H         5
# 10020            861 2034-04-08         579       1014      Book N        19
# 10021           7271 2029-04-26         153       1052      Book T        10
#
# ...
